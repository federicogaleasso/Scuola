# %% [markdown]
# Il **Natural Language Processing** è il campo dell'Intelligenza Artificiale relativo al trattamento automatico del linguaggio naturale (ossia le lingue che parliamo).
#
# I dati analizzati in questo ambito sono linguistici == Testi

# %% [markdown]
# #Primi passi con le STRINGHE

# %%
x = "Ciao!"
print(x)
# Out:
# Ciao!

# %%
x

# %% [markdown]
# >Le stringhe sono sequenze alfanumeriche di
# caratteri delimitate da singoli (‘ciao’) o  doppi  (“ciao”) apici.
#
# Documentazione:
# 1. https://docs.python.org/3/library/stdtypes.html
# 2. https://www.python.it/doc/Howtothink/Howtothink-html-it/chap07.htm

# %% [markdown]
# 1. assegna alla variabile *x* il testo ***il mare d'inverno***
#
# >Il backslash (\\) è il carattere di escape, es: `'un bicchiere d\'acqua'`

# %%
# inserisci qui il tuo codice
x = "il mare d\'inverno"
print(x)
# Out:
# il mare d'inverno

# %% [markdown]
# Operatori per concatenare e ripetere sequenze: + e *

# %% [markdown]
# 2. x='Ciao' e y='Mondo', concatena le variabili x e y per creare la frase *Ciao Mondo*
#
# > operatore +, es: `"Viva "+"Python!"`

# %%
# inserisci qui il tuo codice
x='Ciao'
y='Mondo'
print(x +" "+ y + "!")
# Out:
# Ciao Mondo!

# %% [markdown]
# 3. esegui la moltiplicazione di 10 * 3
#
# > la moltiplicazione può avvenire solo tra variabili dello stesso tipo, es tra interi (`int()`) o stringhe (`str()`)

# %%
x = '10'
print('Prodotto:',int(x)*3)
# Out:
# Prodotto: 30

# %% [markdown]
# 4. scrivi la parola *Banana* usando l'operatore *

# %%
# inserisci qui il tuo codice
x="B"
y="a"
z="n"
print(x+y+(z+y)*2)
# Out:
# Banana

# %% [markdown]
# 5. concatena le variabili x = 10 e y = "il mio voto è " per creare la frase *il mio voto è 10*

# %%
x = 10

# inserisci qui il tuo codice

# %% [markdown]
# 6. assegna alla variabile x una parola in input che possa completare la frase *voglio...*, usando la funzione [input()](https://docs.python.org/3/library/functions.html#input)

# %%
y = "voglio... "
x = input() 
print(y + x )
# Out:
# arrampicare!
# voglio... arrampicare!

# %%
somma=0
for i in range (2):
    x = input()
    somma += int(x)
    print(somma)

# %% [markdown]
# Stringa come lista di `['c','a','r','a','t','t','e','r','i']`

# %% [markdown]
# 7. stampa la lunghezza della parola *#DeactivHate*
#
# > metodo consigliato: [len()](https://www.python.it/doc/Howtothink/Howtothink-html-it/chap07.htm)

# %%
# inserisci qui il tuo codice
x='#DeactivHate'
len(x)
# Out:
# 12

# %% [markdown]
# 8. estrai il primo e il settimo carattere della parola *#DeactivHate*

# %%
# inserisci qui il tuo codice
x = '#DeactivHate'
x[0]
# Out:
# '#'

# %% [markdown]
# 9. estrai dall'ottavo fino all'ultimo carattere della parola *#DeactivHate*

# %%
# inserisci qui il tuo codice
x = '#DeactivHate'
x[7:]
# Out:
# 'vHate'

# %% [markdown]
# Operatori di contenimento: [*in* e *not in*](https://docs.python.org/3/reference/expressions.html#not-in)

# %% [markdown]
# 10. verifica se i caratteri *ac* e *eg* sono all'interno della parola *#DeactivHate*

# %%
# inserisci qui il tuo codice
x = '#DeactivHate'
if ("ac" in x or "eg" in x):
    print("Contiene i caratteri ac o eg")
else:
    print("Non contiene i caratteri ac o eg")
# Out:
# Contiene i caratteri ac o eg

# %% [markdown]
# Maiuscolo e minuscolo: [upper() e lower()](https://docs.python.org/3/library/stdtypes.html#str.upper)

# %% [markdown]
# 11. converti in maiuscolo solo la *d* e la *h* della parola *deactivhate*

# %%
# inserisci qui il tuo codice
x = 'deactivhate'
'd'.upper()+'eactive'+'h'.upper()+'ate'
# Out:
# 'DeactiveHate'

# %% [markdown]
# Pulizia del testo

# %% [markdown]
# 12. elimina la stringa '@user' dal testo '@user @user Rimpatriare delinquenti è fare la guerra ai poveri? Io non voglio dare un euro a migranti, clandestini, rom, delinquenti e feccia varia.', usando il metodo [replace()](https://docs.python.org/3/library/stdtypes.html#str.replace)

# %%
testo = "@user @user Rimpatriare delinquenti è fare la guerra ai poveri? Io non voglio dare un euro a migranti, clandestini, rom, delinquenti e feccia varia."
testo_SenzaUser =  testo.replace("@user","")
print(testo_SenzaUser)
# Out:
#   Rimpatriare delinquenti è fare la guerra ai poveri? Io non voglio dare un euro a migranti, clandestini, rom, delinquenti e feccia varia.

# %% [markdown]
# 13. la stringa risultante dall'esercizio (12) ha degli spazi in più, eliminali usando il metodo [strip()](https://docs.python.org/3/library/stdtypes.html#str.strip)

# %%
testo_SenzaSpaziInPiu =  testo_SenzaUser.strip()   
print(testo_SenzaUser)
# Out:
#   Rimpatriare delinquenti è fare la guerra ai poveri? Io non voglio dare un euro a migranti, clandestini, rom, delinquenti e feccia varia.

# %% [markdown]
# 14. inserisci uno spazio prima di ogni segno di punteggiatura nel testo risultante dall'esercizio (13)

# %% [markdown]
# usa il ciclo [for](https://www.python.it/doc/Easytut/easytut-it/node11.html) e se necessario le condizioni [if, elif, else](https://www.python.it/doc/Howtothink/Howtothink-html-it/chap04.htm#4)

# %%
punt = ['.', '?', '!', ',']
testo_senzaPunt = ''

for i in testo_SenzaSpaziInPiu:
  if (i in punt):
    testo_senzaPunt += " " + i
  else:
    testo_senzaPunt += i

print(testo_senzaPunt)
# Out:
# Rimpatriare delinquenti è fare la guerra ai poveri ? Io non voglio dare un euro a migranti , clandestini , rom , delinquenti e feccia varia .

# %% [markdown]
# 15. converti tutte le lettere del testo risultante dall'esercizio (14) in minuscolo

# %%
testo_in_minuscolo =                            # da completare

# %% [markdown]
# Estraiamo le parole significanti e creiamo il vocabolario

# %% [markdown]
# 16. converti la stringa risultante dall'esercizio (15) in una lista di tokens, usando il metodo [split()](https://docs.python.org/3/library/stdtypes.html)

# %% [markdown]
# > i tokens sono tutte le unità linguistiche del testo: parole, segni di punteggiatura e altro

# %%
lista_tokens =                                # da completare

# %% [markdown]
# 17. elimina le parole molto comuni (dette anche stopwords) dalla lista di tokens risultante dall'esercizio (16)

# %% [markdown]
# > le stopwords sono tutte quelle parole che hanno una funzione prettamente grammaticale come le preposizioni, gli articoli, ecc...

# %%
stopwords = ['ai', 'si', 'che', 'come', 'di', 'a', 'da', 'su', 'per', 'tra', 'fra', 'con', 'e', 'ed', 'il', 'la', 'le', 'gli', 'i', 'lo', 'non', 'un', 'una', 'degli', 'dell', 'delle', 'della']
lista_tokens_senzaSW = []

# inserisci qui il tuo codice

# %% [markdown]
# 18. elimina i segni di punteggiatura dalla lista dei tokens risultante dall'esercizio (17), creando così il vocabolario del testo

# %%
vocabolario = []

# inserisci qui il tuo codice

# %% [markdown]
# 19. conta quante volte ogni parola è contenuta nel vocabolario, usando il metodo [count()](https://docs.python.org/3/tutorial/datastructures.html) applicato alle liste

# %%
# inserisci qui il tuo codice

# %% [markdown]
# 20. stampa la lunghezza del vocabolario contenente stavolta una occorrenza per ogni parola, convertendo la lista in un [set()](https://docs.python.org/3/tutorial/datastructures.html#sets)

# %%
vocabolario_ParoleUniche =                            # da completare
